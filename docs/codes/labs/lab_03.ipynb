# %% [markdown]
# <a href="https://colab.research.google.com/github/fralfaro/MAT306/blob/main/docs/labs/lab_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
#
# # MAT306 - Laboratorio N°03

# %% [markdown]
# **Objetivo**: Aplicar técnicas avanzadas de manipulación y análisis de datos con pandas sobre un conjunto real de datos de contenido de Netflix, reforzando buenas prácticas y métodos eficientes sin recurrir a `groupby`, `merge`, `pivot`, ni `join`.
#
#
#
# **Dataset**:
#
# Trabajaremos con el archivo `netflix_titles.csv`, que contiene información sobre los títulos disponibles en la plataforma Netflix hasta el año 2021.
#
# | Variable       | Clase     | Descripción                                                                 |
# |----------------|-----------|------------------------------------------------------------------------------|
# | show_id        | caracter  | Identificador único del título en el catálogo de Netflix.                   |
# | type           | caracter  | Tipo de contenido: 'Movie' o 'TV Show'.                                     |
# | title          | caracter  | Título del contenido.                                                       |
# | director       | caracter  | Nombre del director (puede ser nulo).                                       |
# | cast           | caracter  | Lista de actores principales (puede ser nulo).                              |
# | country        | caracter  | País o países donde se produjo el contenido.                                |
# | date_added     | fecha     | Fecha en la que el título fue agregado al catálogo de Netflix.              |
# | release_year   | entero    | Año de lanzamiento original del título.                                     |
# | rating         | caracter  | Clasificación por edad (por ejemplo: 'PG-13', 'TV-MA').                      |
# | duration       | caracter  | Duración del contenido (minutos o número de temporadas para series).        |
# | listed_in      | caracter  | Categorías o géneros en los que está clasificado el contenido.              |
# | description    | caracter  | Breve sinopsis del contenido.                                               |

# %%
import pandas as pd

# %%
# Cargar datos
df = pd.read_csv('https://raw.githubusercontent.com/fralfaro/MAT306/main/docs/labs/data/netflix_titles.csv')
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %% [markdown]
# ### Parte 1: Limpieza y preparación
#
# 1. Revisar y describir el dataset:
#
#    * ¿Cuántas filas y columnas tiene?
#    * ¿Qué tipos de datos hay?
#    * ¿Cuántos valores nulos hay por columna?
#
# 2. Transformar la columna `date_added` a tipo fecha.
#
# 3. Crear columnas auxiliares con `assign`:
#
#    * Año (`year_added`)
#    * Mes (`month_added`)

# %%
#Tamñano de dataframe
print("El dataframe posee", df.shape[0], "Filas y ", df.shape[1], "columnas")
# Out:
# El dataframe posee 8807 Filas y  12 columnas

# %%
#Tipos de dato segun cada columna
print("\nTipos de datos: \n", df.dtypes)
# Out:
# Tipos de datos:
#  show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#valores nulos por columna
print("Valores nulos por columna: \n", df.isnull().sum())
# Out:
# Valores nulos por columna:
#  show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
import datetime

#ELiminamos primero espacios en blanco, pues presenta problemas al momento de convertir al formato fecha
df["date_added"] = df["date_added"].str.strip()

#Pasamos a formato fecha
df["date_added"] = pd.to_datetime(df["date_added"], format="%B %d, %Y")

df["date_added"].dtype      # <M8[ns] = datetime64[ns]
# Out:
# dtype('<M8[ns]')

# %%
#Creamos columnas auxiliares
df = df.assign( year_added = df["date_added"].dt.year, month_added = df["date_added"].dt.month)
df[["year_added", "month_added"]]
# Out:
#       year_added  month_added
# 0         2021.0          9.0
# 1         2021.0          9.0
# 2         2021.0          9.0
# 3         2021.0          9.0
# 4         2021.0          9.0
# ...          ...          ...
# 8802      2019.0         11.0
# 8803      2019.0          7.0
# 8804      2019.0         11.0
# 8805      2020.0          1.0
# 8806      2019.0          3.0
#
# [8807 rows x 2 columns]

# %% [markdown]
# ## Parte 2: Técnicas avanzadas de pandas
#
# 4. Utilizar `.loc` para seleccionar películas (`type == 'Movie'`) que fueron agregadas después del año 2018.
#
# 5. Utilizar `str.contains()` y `str.extract()`:
#
#    * Filtrar títulos que contienen la palabra 'love' (sin distinguir mayúsculas/minúsculas).
#    * Extraer la duración en minutos para las películas desde la columna `duration`.
#
# 6. Aplicar `explode()` sobre la columna `listed_in` para obtener una fila por cada género.
#
# 7. Obtener un top 10 de géneros más frecuentes utilizando `value_counts()`.
#
# 8. Aplicar `where()` y `mask()` para marcar las películas de más de 120 minutos como contenido largo en una nueva columna.
#
# 9. Utilizar `.loc` para filtrar películas que cumplen con:
#
#    * Más de 100 minutos de duración.
#    * Rating igual a `'R'`.
#    * País igual a `'United States'`.
#
# 10. Utilizar `.style` para formatear visualmente el top 10 de películas más largas.

# %%
#Creamos una copia del df incluyendo solo peliculas
df_movies = df.loc[df["type"] == "Movie"].copy()

#Filtramos las peliculas
df_movies.loc[df_movies["year_added"] > 2018]
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8798   s8799  Movie                          Zed Plus
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8798        Chandra Prakash Dwivedi
# 8802                  David Fincher
# 8804                Ruben Fleischer
# 8805                   Peter Hewitt
# 8806                    Mozez Singh
#
#                                                    cast  \
# 0                                                   NaN
# 6     Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 7     Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 9     Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12    Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# ...                                                 ...
# 8798  Adil Hussain, Mona Singh, K.K. Raina, Sanjay M...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8804  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
#
#                                                 country date_added  \
# 0                                         United States 2021-09-25
# 6                                                   NaN 2021-09-24
# 7     United States, Ghana, Burkina Faso, United Kin... 2021-09-24
# 9                                         United States 2021-09-24
# 12                              Germany, Czech Republic 2021-09-23
# ...                                                 ...        ...
# 8798                                              India 2019-12-31
# 8802                                      United States 2019-11-20
# 8804                                      United States 2019-11-01
# 8805                                      United States 2020-01-11
# 8806                                              India 2019-03-02
#
#       release_year rating duration  \
# 0             2020  PG-13   90 min
# 6             2021     PG   91 min
# 7             1993  TV-MA  125 min
# 9             2021  PG-13  104 min
# 12            2021  TV-MA  127 min
# ...            ...    ...      ...
# 8798          2014  TV-MA  131 min
# 8802          2007      R  158 min
# 8804          2009      R   88 min
# 8805          2006     PG   88 min
# 8806          2015  TV-14  111 min
#
#                                              listed_in  \
# 0                                        Documentaries
# 6                             Children & Family Movies
# 7     Dramas, Independent Movies, International Movies
# 9                                     Comedies, Dramas
# 12                        Dramas, International Movies
# ...                                                ...
# 8798            Comedies, Dramas, International Movies
# 8802                    Cult Movies, Dramas, Thrillers
# 8804                           Comedies, Horror Movies
# 8805                Children & Family Movies, Comedies
# 8806    Dramas, International Movies, Music & Musicals
#
#                                             description  year_added  \
# 0     As her father nears the end of his life, filmm...      2021.0
# 6     Equestria's divided. But a bright-eyed hero be...      2021.0
# 7     On a photo shoot in Ghana, an American model s...      2021.0
# 9     A woman adjusting to life after a loss contend...      2021.0
# 12    After most of her family is murdered in a terr...      2021.0
# ...                                                 ...         ...
# 8798  A philandering small-town mechanic's political...      2019.0
# 8802  A political cartoonist, a crime reporter and a...      2019.0
# 8804  Looking to survive in a world taken over by zo...      2019.0
# 8805  Dragged from civilian life, a former superhero...      2020.0
# 8806  A scrappy but poor boy worms his way into a ty...      2019.0
#
#       month_added
# 0             9.0
# 6             9.0
# 7             9.0
# 9             9.0
# 12            9.0
# ...           ...
# 8798         12.0
# 8802         11.0
# 8804         11.0
# 8805          1.0
# 8806          3.0
#
# [3701 rows x 14 columns]

# %%
#Filtramos segun si tiene la palabra "love"
df.loc[df["title"].str.contains(" love ", case=False)]
# Out:
#      show_id     type                                              title  \
# 506     s507    Movie                           This Little Love Of Mine
# 659     s660  TV Show                    Bangkok Love Stories: Innocence
# 849     s850    Movie  Sam Smith: Love Goes - Live at Abbey Road Studios
# 1161   s1162    Movie           Elizabeth and Margaret: Love and Loyalty
# 1428   s1429    Movie                                Is Love Enough? Sir
# 1483   s1484  TV Show                                A Love So Beautiful
# 1509   s1510    Movie               Ariana grande: excuse me, i love you
# 1525   s1526    Movie                        Eggnoid: Love & Time Portal
# 1669   s1670    Movie                     If Anything Happens I Love You
# 1962   s1963    Movie                            A Love Song for Latasha
# 2034   s2035    Movie                               So Much Love to Give
# 2507   s2508  TV Show                   Patton Oswalt: I Love Everything
# 2521   s2522    Movie                                 I love you, stupid
# 2885   s2886    Movie                                  When Love Happens
# 2925   s2926    Movie             To All the Boys: P.S. I Still Love You
# 2977   s2978  TV Show                 Ainori Love Wagon: African Journey
# 3044   s3045    Movie                              Live Twice, Love Once
# 3083   s3084  TV Show                                 Pucca: Love Recipe
# 3413   s3414    Movie                                   Verses of Love 2
# 3688   s3689  TV Show         Bangkok Love Stories: Objects of Affection
# 3689   s3690  TV Show                        Bangkok Love Stories: Plead
# 3971   s3972  TV Show                   Ainori Love Wagon: Asian Journey
# 4017   s4018    Movie                                       A Love Story
# 4018   s4019    Movie                           Barcelona: A Love Untold
# 4029   s4030  TV Show                     Bangkok Love Stories: Hey You!
# 4041   s4042    Movie                                    The Love Affair
# 4046   s4047    Movie                                Everyday I Love You
# 4419   s4420    Movie                      They’ll Love Me When I’m Dead
# 4735   s4736    Movie                             Tere Naal Love Ho Gaya
# 5439   s5440  TV Show                                  My Only Love Song
# 5693   s5694    Movie                              For the Love of Spock
# 5766   s5767  TV Show                               Fall in Love with Me
# 5956   s5957    Movie                            Just Another Love Story
# 6059   s6060    Movie                        A Tale of Love and Darkness
1 Season  International TV Shows, Romantic TV Shows, TV ...
# 5956    104 min                       Dramas, International Movies
# 6059     98 min                       Dramas, International Movies
# 6060    108 min                          Comedies, Romantic Movies
# 6120     91 min                                      Horror Movies
# 6286    120 min      Dramas, International Movies, Romantic Movies
# 6444     86 min      Dramas, International Movies, Romantic Movies
# 6477   1 Season                                         Docuseries
# 6779     95 min                                           Comedies
# 6781     84 min                           Children & Family Movies
# 6929     95 min                                      Documentaries
# 7046    116 min    Comedies, International Movies, Romantic Movies
# 7049    119 min      Dramas, Faith & Spirituality, Romantic Movies
# 7352    115 min    Comedies, International Movies, Romantic Movies
# 7518    102 min                Documentaries, International Movies
# 7632   1 Season  International TV Shows, Romantic TV Shows, TV ...
# 7690    126 min                            Dramas, Romantic Movies
# 8406     87 min                            Comedies, Sports Movies
#
#                                             description  year_added  \
# 506   A workaholic lawyer returns to her island home...      2021.0
# 659   From a teenage parkour enthusiast to a bawdy r...      2021.0
# 849   Grammy-winning artist Sam Smith gives an intim...      2021.0
# 1161  This documentary takes an intimate look at the...      2021.0
# 1428  A young widow is hired as the domestic helper ...      2021.0
# 1483  Love is as tough as it is sweet for a lovestru...      2020.0
# 1509  Ariana Grande takes the stage in London for he...      2020.0
# 1525  Sent from the future to look after a lonely gi...      2020.0
# 1669  Grieving parents journey through an emotional ...      2020.0
# 1962  The killing of Latasha Harlins became a flashp...      2020.0
# 2034  Fernando is a family man — equally committed t...      2020.0
# 2507  Turning 50. Finding love again. Buying a house...      2020.0
# 2521  After Marcos is dumped by his girlfriend, he a...      2020.0
# 2885  Fed up with coordinating weddings for everyone...      2020.0
# 2925  Lara Jean is officially Peter’s girlfriend, so...      2020.0
# 2977  To find love, seven strangers leave Japan and ...      2020.0
# 3044  When Emilio (Oscar Martínez) is diagnosed with...      2020.0
# 3083  Faced with a threat to the survival of her fam...      2019.0
# 3413  Now a lecturer in Edinburgh, Fahri tries to be...      2019.0
# 3688  A kind computer repairman falls for a street-s...      2019.0
# 3689  In Bangkok's Chinatown, a spirited digital mar...      2019.0
# 3971  Seven men and women board a pink bus in search...      2019.0
# 4017  Self-made millionaire Ian thinks he's found ha...      2019.0
# 4018  While pursuing a degree in Spain, an architect...      2019.0
# 4029  A loving couple become rivals when Belle opens...      2019.0
# 4041  Feeling betrayed by their romantic partners' i...      2019.0
# 4046  While patiently waiting for her boyfriend to c...      2019.0
# 4419  Actors, crew members and others who were there...      2018.0
# 4735  Mini isn't eager to wed the rich suitor who's ...      2018.0
# 5439  When things don't go her way during a shooting...      2017.0
# 5693  The son of actor Leonard Nimoy directs this mo...      2016.0
# 5766  The head of a struggling ad agency finds herse...      2016.0
# 5956  When he causes a car accident that leaves a yo...      2009.0
# 6059  Based on the memoirs of author Amos Oz, this p...      2019.0
# 6060  When a philandering club promoter sets out to ...      2020.0
# 6120  During a weekend excursion to a secluded ranch...      2018.0
# 6286  Set in the Grey City, this "Cities of Love" in...      2019.0
# 6444  Spanning the 1970s, ‘80s and ‘90s, this lyrica...      2019.0
# 6477  A contextual, acculturated dive into how adult...      2018.0
# 6779  When a goofy but likable millionaire discovers...      2019.0
# 6781  Benji and his owner get separated in Greece. O...      2018.0
# 6929  Storyboard artist Harold Michelson and his fil...      2018.0
# 7046  Desperate to go to the U.S. to win back his gi...      2018.0
# 7049  When a tough-minded ex-drug dealer falls for a...      2017.0
# 7352  A love triangle gets complicated when a female...      2019.0
# 7518  World-renowned choreographer Ohad Naharin is p...      2017.0
# 7632  Five schoolmates who share a blood type naviga...      2018.0
# 7690  When she loses her beloved husband to a brain ...      2019.0
# 8406  Raised on an ashram in India, a self-styled lo...      2019.0
#
#       month_added
# 506           7.0
# 659           6.0
# 849           5.0
# 1161          3.0
# 1428          1.0
# 1483         12.0
# 1509         12.0
# 1525         12.0
# 1669         11.0
# 1962          9.0
# 2034          9.0
# 2507          5.0
# 2521          5.0
# 2885          2.0
# 2925          2.0
# 2977          1.0
# 3044          1.0
# 3083         12.0
# 3413         10.0
# 3688          7.0
# 3689          7.0
# 3971          3.0
# 4017          3.0
# 4018          3.0
# 4029          3.0
# 4041          3.0
# 4046          3.0
# 4419         11.0
# 4735          8.0
# 5439          6.0
# 5693         12.0
# 5766         10.0
# 5956          5.0
# 6059         10.0
# 6060         12.0
# 6120          7.0
# 6286          6.0
# 6444          1.0
# 6477          9.0
# 6779          8.0
# 6781          3.0
# 6929         11.0
# 7046          9.0
# 7049         10.0
# 7352          1.0
# 7518          6.0
# 7632          4.0
# 7690          4.0
# 8406         11.0

# %%
#Creamos la columna de duracion en minutos que contenga solo el valor
df_movies["duration_min"] = df_movies["duration"].str.extract("(\\d+)")
df_movies["duration_min"]
# Out:
# 0        90
# 6        91
# 7       125
# 9       104
# 12      127
#        ...
# 8801     96
# 8802    158
# 8804     88
# 8805     88
# 8806    111
# Name: duration_min, Length: 6131, dtype: object

# %%
#Copiamos el dataframe
df_ex = df.copy()

#Solucionamos problemas de formato y aplicamos explode
df_ex["listed_in"] = df_ex["listed_in"].str.split(",")
df_ex = df_ex.explode("listed_in")

df_ex
# Out:
#      show_id     type                 title         director  \
# 0         s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show         Blood & Water              NaN
# 1         s2  TV Show         Blood & Water              NaN
# 1         s2  TV Show         Blood & Water              NaN
# 2         s3  TV Show             Ganglands  Julien Leclercq
# ...      ...      ...                   ...              ...
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8805   s8806    Movie                  Zoom     Peter Hewitt
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
# 8806   s8807    Movie                Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2     Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# ...                                                 ...            ...
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8805  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
# 8806  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...          India
#
#      date_added  release_year rating   duration                 listed_in  \
# 0    2021-09-25          2020  PG-13     90 min             Documentaries
# 1    2021-09-24          2021  TV-MA  2 Seasons    International TV Shows
# 1    2021-09-24          2021  TV-MA  2 Seasons                 TV Dramas
# 1    2021-09-24          2021  TV-MA  2 Seasons              TV Mysteries
# 2    2021-09-24          2021  TV-MA   1 Season            Crime TV Shows
# ...         ...           ...    ...        ...                       ...
# 8805 2020-01-11          2006     PG     88 min  Children & Family Movies
# 8805 2020-01-11          2006     PG     88 min                  Comedies
# 8806 2019-03-02          2015  TV-14    111 min                    Dramas
# 8806 2019-03-02          2015  TV-14    111 min      International Movies
# 8806 2019-03-02          2015  TV-14    111 min          Music & Musicals
#
#                                             description  year_added  \
# 0     As her father nears the end of his life, filmm...      2021.0
# 1     After crossing paths at a party, a Cape Town t...      2021.0
# 1     After crossing paths at a party, a Cape Town t...      2021.0
# 1     After crossing paths at a party, a Cape Town t...      2021.0
# 2     To protect his family from a powerful drug lor...      2021.0
# ...                                                 ...         ...
# 8805  Dragged from civilian life, a former superhero...      2020.0
# 8805  Dragged from civilian life, a former superhero...      2020.0
# 8806  A scrappy but poor boy worms his way into a ty...      2019.0
# 8806  A scrappy but poor boy worms his way into a ty...      2019.0
# 8806  A scrappy but poor boy worms his way into a ty...      2019.0
#
#       month_added
# 0             9.0
# 1             9.0
# 1             9.0
# 1             9.0
# 2             9.0
# ...           ...
# 8805          1.0
# 8805          1.0
# 8806          3.0
# 8806          3.0
# 8806          3.0
#
# [19323 rows x 14 columns]

# %%
#10 generos mas repetidos
df_ex["listed_in"].value_counts().head(10)
# Out:
# listed_in
#  International Movies     2624
# Dramas                    1600
# Comedies                  1210
# Action & Adventure         859
# Documentaries              829
#  Dramas                    827
# International TV Shows     774
#  Independent Movies        736
#  TV Dramas                 696
#  Romantic Movies           613
# Name: count, dtype: int64

# %%
#Rellenamos valores vacios con cero y separamos
df_movies["duration_min"] = df_movies["duration_min"].fillna(0).astype(int)

df_movies["Contenido_largo"] = df_movies["duration_min"].where(df_movies["duration_min"] > 120, other="Corto")
df_movies["Contenido_largo"] = df_movies["Contenido_largo"].mask(df_movies["duration_min"] > 120, other="Largo")

df_movies["Contenido_largo"]
# Out:
# 0       Corto
# 6       Corto
# 7       Largo
# 9       Corto
# 12      Largo
#         ...
# 8801    Corto
# 8802    Largo
# 8804    Corto
# 8805    Corto
# 8806    Corto
# Name: Contenido_largo, Length: 6131, dtype: object

# %%
#Filtramos segun criterios
df_movies.loc[(df_movies["duration_min"] > 100) & (df_movies["rating"] == "R") & (df_movies["country"] == "United States")]
# Out:
#      show_id   type                        title               director  \
# 48       s49  Movie                 Training Day          Antoine Fuqua
# 81       s82  Movie                         Kate  Cedric Nicolas-Troyan
# 131     s132  Movie  Blade Runner: The Final Cut           Ridley Scott
# 139     s140  Movie           Do the Right Thing              Spike Lee
# 144     s145  Movie                  House Party        Reginald Hudlin
# ...      ...    ...                          ...                    ...
# 8678   s8679  Movie              Vincent N Roxxy   Gary Michael Schultz
# 8691   s8692  Movie                    Wakefield          Robin Swicord
# 8751   s8752  Movie              Wish I Was Here             Zach Braff
# 8754   s8755  Movie                       Wolves        Bart Freundlich
# 8802   s8803  Movie                       Zodiac          David Fincher
#
#                                                    cast        country  \
# 48    Denzel Washington, Ethan Hawke, Scott Glenn, T...  United States
# 81    Mary Elizabeth Winstead, Jun Kunimura, Woody H...  United States
# 131   Harrison Ford, Rutger Hauer, Sean Young, Edwar...  United States
# 139   Danny Aiello, Ossie Davis, Ruby Dee, Richard E...  United States
# 144   Christopher Reid, Christopher Martin, Robin Ha...  United States
# ...                                                 ...            ...
# 8678  Emile Hirsch, Zoë Kravitz, Emory Cohen, Zoey D...  United States
# 8691  Bryan Cranston, Jennifer Garner, Jason O'Mara,...  United States
# 8751  Zach Braff, Kate Hudson, Donald Faison, Joey K...  United States
# 8754  Michael Shannon, Carla Gugino, Taylor John Smi...  United States
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...  United States
#
#      date_added  release_year rating duration  \
# 48   2021-09-16          2001      R  122 min
# 81   2021-09-10          2021      R  106 min
# 131  2021-09-01          1982      R  117 min
# 139  2021-09-01          1989      R  120 min
# 144  2021-09-01          1990      R  104 min
# ...         ...           ...    ...      ...
# 8678 2017-09-02          2016      R  101 min
# 8691 2019-03-02          2016      R  109 min
# 8751 2018-08-16          2014      R  106 min
# 8754 2019-03-29          2016      R  109 min
# 8802 2019-11-20          2007      R  158 min
#
#                                             listed_in  \
# 48                                  Dramas, Thrillers
# 81                                 Action & Adventure
# 131   Action & Adventure, Classic Movies, Cult Movies
# 139                  Classic Movies, Comedies, Dramas
# 144                             Comedies, Cult Movies
# ...                                               ...
# 8678                                Dramas, Thrillers
# 8691                                           Dramas
# 8751             Comedies, Dramas, Independent Movies
# 8754        Dramas, Independent Movies, Sports Movies
# 8802                   Cult Movies, Dramas, Thrillers
#
#                                             description  year_added  \
# 48    A rookie cop with one day to prove himself to ...      2021.0
# 81    Slipped a fatal poison on her final job, a rut...      2021.0
# 131   In a smog-choked dystopian Los Angeles, blade ...      2021.0
# 139   On a sweltering day in Brooklyn, simmering rac...      2021.0
# 144   Grounded by his strict father, Kid risks life ...      2021.0
# ...                                                 ...         ...
# 8678  In rural Louisiana, a terse loner forges a red...      2017.0
# 8691  An unhappy father and lawyer quits his suburba...      2019.0
# 8751  With his acting career moribund, Aidan Bloom s...      2018.0
# 8754  A promising high school basketball player has ...      2019.0
# 8802  A political cartoonist, a crime reporter and a...      2019.0
#
#       month_added  duration_min Contenido_largo
# 48            9.0           122           Largo
# 81            9.0           106           Corto
# 131           9.0           117           Corto
# 139           9.0           120           Corto
# 144           9.0           104           Corto
# ...           ...           ...             ...
# 8678          9.0           101           Corto
# 8691          3.0           109           Corto
# 8751          8.0           106           Corto
# 8754          3.0           109           Corto
# 8802         11.0           158           Largo
#
# [243 rows x 16 columns]

# %%
#pip install jinja2

# %%
#Guardamos las mejores 10 peliculas
top10 = df_movies.sort_values("duration_min", ascending=False).head(10)

# Resaltar fila completa de cada película
top10.style.apply(lambda x: ["background-color: brown" for _ in x], axis=1)
# Out:
# <style type="text/css">
# #T_d2c35_row0_col0, #T_d2c35_row0_col1, #T_d2c35_row0_col2, #T_d2c35_row0_col3, #T_d2c35_row0_col4, #T_d2c35_row0_col5, #T_d2c35_row0_col6, #T_d2c35_row0_col7, #T_d2c35_row0_col8, #T_d2c35_row0_col9, #T_d2c35_row0_col10, #T_d2c35_row0_col11, #T_d2c35_row0_col12, #T_d2c35_row0_col13, #T_d2c35_row0_col14, #T_d2c35_row0_col15, #T_d2c35_row1_col0, #T_d2c35_row1_col1, #T_d2c35_row1_col2, #T_d2c35_row1_col3, #T_d2c35_row1_col4, #T_d2c35_row1_col5, #T_d2c35_row1_col6, #T_d2c35_row1_col7, #T_d2c35_row1_col8, #T_d2c35_row1_col9, #T_d2c35_row1_col10, #T_d2c35_row1_col11
8_col9, #T_d2c35_row8_col10, #T_d2c35_row8_col11, #T_d2c35_row8_col12, #T_d2c35_row8_col13, #T_d2c35_row8_col14, #T_d2c35_row8_col15, #T_d2c35_row9_col0, #T_d2c35_row9_col1, #T_d2c35_row9_col2, #T_d2c35_row9_col3, #T_d2c35_row9_col4, #T_d2c35_row9_col5, #T_d2c35_row9_col6, #T_d2c35_row9_col7, #T_d2c35_row9_col8, #T_d2c35_row9_col9, #T_d2c35_row9_col10, #T_d2c35_row9_col11, #T_d2c35_row9_col12, #T_d2c35_row9_col13, #T_d2c35_row9_col14, #T_d2c35_row9_col15 {
#   background-color: brown;
# }
# </style>
# <table id="T_d2c35">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d2c35_level0_col0" class="col_heading level0 col0" >show_id</th>
#       <th id="T_d2c35_level0_col1" class="col_heading level0 col1" >type</th>
#       <th id="T_d2c35_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_d2c35_level0_col3" class="col_heading level0 col3" >director</th>
#       <th id="T_d2c35_level0_col4" class="col_heading level0 col4" >cast</th>
#       <th id="T_d2c35_level0_col5" class="col_heading level0 col5" >country</th>
#       <th id="T_d2c35_level0_col6" class="col_heading level0 col6" >date_added</th>
#       <th id="T_d2c35_level0_col7" class="col_heading level0 col7" >release_year</th>
#       <th id="T_d2c35_level0_col8" class="col_heading level0 col8" >rating</th>
#       <th id="T_d2c35_level0_col9" class="col_heading level0 col9" >duration</th>
#       <th id="T_d2c35_level0_col10" class="col_heading level0 col10" >listed_in</th>
#       <th id="T_d2c35_level0_col11" class="col_heading level0 col11" >description</th>
#       <th id="T_d2c35_level0_col12" class="col_heading level0 col12" >year_added</th>
#       <th id="T_d2c35_level0_col13" class="col_heading level0 col13" >month_added</th>
#       <th id="T_d2c35_level0_col14" class="col_heading level0 col14" >duration_min</th>
#       <th id="T_d2c35_level0_col15" class="col_heading level0 col15" >Contenido_largo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d2c35_level0_row0" class="row_heading level0 row0" >4253</th>
#       <td id="T_d2c35_row0_col0" class="data row0 col0" >s4254</td>
#       <td id="T_d2c35_row0_col1" class="data row0 col1" >Movie</td>
#       <td id="T_d2c35_row0_col2" class="data row0 col2" >Black Mirror: Bandersnatch</td>
#       <td id="T_d2c35_row0_col3" class="data row0 col3" >nan</td>
#       <td id="T_d2c35_row0_col4" class="data row0 col4" >Fionn Whitehead, Will Poulter, Craig Parkinson, Alice Lowe, Asim Chaudhry</td>
#       <td id="T_d2c35_row0_col5" class="data row0 col5" >United States</td>
#       <td id="T_d2c35_row0_col6" class="data row0 col6" >2018-12-28 00:00:00</td>
#       <td id="T_d2c35_row0_col7" class="data row0 col7" >2018</td>
#       <td id="T_d2c35_row0_col8" class="data row0 col8" >TV-MA</td>
#       <td id="T_d2c35_row0_col9" class="data row0 col9" >312 min</td>
#       <td id="T_d2c35_row0_col10" class="data row0 col10" >Dramas, International Movies, Sci-Fi & Fantasy</td>
#       <td id="T_d2c35_row0_col11" class="data row0 col11" >In 1984, a young programmer begins to question reality as he adapts a dark fantasy novel into a video game. A mind-bending tale with multiple endings.</td>
#       <td id="T_d2c35_row0_col12" class="data row0 col12" >2018.000000</td>
#       <td id="T_d2c35_row0_col13" class="data row0 col13" >12.000000</td>
#       <td id="T_d2c35_row0_col14" class="data row0 col14" >312</td>
#       <td id="T_d2c35_row0_col15" class="data row0 col15" >Largo</td>
#     </tr>
#     <tr>
#       <th id="T_d2c35_level0_row1" class="row_heading level0 row1" >717</th>
#       <td id="T_d2c35_row1_col0" class="data row1 col0" >s718</td>
#       <td id="T_d2c35_row1_col1" class="data row1 col1" >Movie</td>
#       <td id="T_d2c35_row1_col2" class="data row1 col2" >Headspace: Unwind Your Mind</td>
#       <td id="T_d2c35_row1_col3" class="data row1 col3" >nan</td>
#       <td id="T_d2c35_row1_col4" class="data row1 col4" >Andy Puddicombe, Evelyn Lewis Prieto, Ginger Daniels, Darren Pettie, Simon Prebble, Rhiannon Mcgavin, Kate Seftel</td>
#       <td id="T_d2c35_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_d2c35_row1_col6" class="data row1 col6" >2021-06-15 00:00:00</td>
#       <td id="T_d2c35_row1_col7" class="data row1 col7" >2021</td>
#       <td id="T_d2c35_row1_col8" class="data row1 col8" >TV-G</td>
#       <td id="T_d2c35_row1_col9" class="data row1 col9" >273 min</td>
#       <td id="T_d2c35_row1_col10" class="data row1 col10" >Documentaries</td>
#       <td id="T_d2c35_row1_col11" class="data row1 col11" >Do you want to relax, meditate or sleep deeply? Personalize the experience according to your mood or mindset with this Headspace interactive special.</td>
#       <td id="T_d2c35_row1_col12" class="data row1 col12" >2021.000000</td>
#       <td id="T_d2c35_row1_col13" class="data row1 col13" >6.000000</td>
#       <td id="T_d2c35_row1_col14" class="data row1 col14" >273</td>
#       <td id="T_d2c35_row1_col15" class="data row1 col15" >Largo</td>
#     </tr>
#     <tr>
#       <th id="T_d2c35_level0_row2" class="row_heading level0 row2" >2491</th>
#       <td id="T_d2c35_row2_col0" class="data row2 col0" >s2492</td>
#       <td id="T_d2c35_row2_col1" class="data row2 col1" >Movie</td>
#       <td

# %% [markdown]
# ### Pregunta Desafío
#
# 11. ¿Cuáles son las combinaciones más frecuentes de género y rating en el dataset?
#     (Sugerencia: utilizar `value_counts` con `subset=["genre", "rating"]` después de aplicar `explode()`).
#
#
#
# ### Bonus: Análisis de duplicados y limpieza
#
# 12. ¿Existen películas con el mismo nombre (`title`) pero con distinto año de lanzamiento (`release_year`)?
# 13. ¿Cuántos títulos únicos hay en total en la columna `title`?

# %%
#Las 5 combinaciones mas frecuentes de genero y rating
df_ex.value_counts(subset=["listed_in", "rating"]).head(5)
# Out:
# listed_in              rating
#  International Movies  TV-MA     1074
#                        TV-14     1022
# Dramas                 TV-MA      616
#                        TV-14      428
#  TV Dramas             TV-MA      401
# Name: count, dtype: int64

# %%
df_movies["title"] = df_movies["title"].astype(str)
duplicados = df_movies.loc[df["title"].duplicated()]

print("hay", len(duplicados), "peliculas con el mismo nombre, por lo que no pueden haber peliculas que cumplan con el criterio establecido.")
# Out:
# hay 0 peliculas con el mismo nombre, por lo que no pueden haber peliculas que cumplan con el criterio establecido.

# %%
titulos_unicos = df["title"].nunique()
print("Existen ", df["title"].nunique(), "Titulos de peliculas unicos en total")
# Out:
# Existen  8807 Titulos de peliculas unicos en total
